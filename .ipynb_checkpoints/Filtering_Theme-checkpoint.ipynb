# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import re

# %%
df = pd.read_csv('data_final.csv')
df.columns = ['Theme', 'Company']
print(df.shape)
df.head(2)
# Out:
# (1142, 2)
#    Theme                                            Company
# 0  방탄소년단  ['키이스트', '넷마블', '디피씨', 'SK텔레콤', '드림어스컴퍼니', '경남...
# 1     여름  ['롯데하이마트', '신일전자', '마니커', '이지바이오', '쿠쿠홈시스', '위...

# %%
drop_people = ['황교안',
              '김태년',
              '홍정욱',
              '이낙연',
              '유승민',
              '김병준',
              '윤석열',
              '조국',
              '정치인',
              '유시민',
              '정세균',
              '오세훈',
              '문재인',
              '추미애',
              '이총리',
              '이재명',
              '김세연',
              '임명재',
              '홍준표',
              '안철수']

# %%
drop_verb = ['확산',
        '결렬',
        '매각',
        '본입찰',
        '추진',
        '기대',
        '찾아가',
        '기대가',
        '유망',
        '소식',
        '엇갈린',
        '견인중',
        '복귀',
        '끝났',
        '기대',
        '선언',
        '언급',
        '승인',
        '급등',
        '날뛰',
        '갈등',
        '스쳐간',
        '입각설',
        '전혀',
        '개선',
        '호재',
        '상반된',
        '의무화',
        '상승',
        '찬성',
        '발표',
        '취소',
        '올라',
        '내려',
        '보합',
        '폭등',
        '급락',
        '개발',
        '허용',
        '승인후',
        '다시보',
        '폐지',
        '쑤욱',
        '대두',
        '사과',
        '폐지되',
        '매각설',
        '사태',
        '주목되',
        '약세',
        '등극',
        '승인',
        '예측',
        '떠오르',
        '완치',
        '예정',
        '장기화',
        '강화',
        '예고',
        '허용',
        '늘어',
        '검토',
        '선언',
        '관련',
        '펼치자',
        '요동치',
        '상승세',
        '증가',
        '들썩이',
        '비상',
        '온라인',
        '4관왕',
        '접히니',
        '호평',
        '기세',
        '출마설',
        '확진',
        '계획',
        '국내',
        '증시',
        '끝났',
        '프로젝트',
        '복귀',
        '인한',
        '신중해야',
        '조짐',
        '확정',
        '확대소식',
        '뜬다',
        '초긴장속으',
        '우려',
        '초읽기',
        '한마디',
        '신고',
        '심화',
        '발생',
        '국산화',
        '리스크',
        '히든',
        '움찔',
        '틈새',
        '성사',
        '꿈틀대',
        '오르',
        '당사',
        '테마주엔',
        '쓸어',
        '사용',
        '주목할',
        '새둥지',
        '올해',
        '지명',
        '주력하겠다',
        '흥행',
        '발견',
        '시사',
        '실패',
        '이슈',
        '논란에',
        '이을까',
        '주목할',
        '접수',
        '앞두고',
        '회복세',
        '철회',
        '찾아가',
        '이튿날',
        '확인',
        '어떻길래',
        '의심신고',
        '제안',
        '조짐',
        '뜨면',
        '전망',
        '보도',
        '공급',
        '치료',
        '발병',
        '대체',
        '치명적이길래',
        '견인중',
        '바닥론',
        '매수해',
        '뭐길래',
        '앞두고',
        '문제',
        '채택',
        '후보자',
        '참여',
        '언급',
        '도입',
        '개시에',
        '부상'
       ]

# %%
drop_etc = ['관련주',
             '관련',
             '수혜',
           '대표주',
           'IT대표주',
           '신규상장',
           '묻지마',
           '지주회사',
           '1위',
           '2파전',
           'IPO',
           '지분털기',
           '증시',
           'VS',
           '합병',
           '소식',
           '고소',
           '위기',
           '3\%',
           '5\%',
           '수익',
           '기업공개',
           '여름',
           '겨울',
           '공포',
           '규제',
           '임상소식',
           '임상체계',
           '연구결과',
           '플랫폼',
           '프로젝트',
           'IT',
           '호실적',
           '가속',
           '본입찰',
           '한반',
           '피눈물',
            '기대↑',
            '집중투자'
            '부재',
            '무늬',
            '끝나니',
            '가능성',
            '남자',
            '허당',
            '차질',
            '앞둔', '무늬', '끝나니', '정치', '총선', '정책', '이긴', '투자전략', '당선', '꺾인',
'지원', '급등주', '몰리', '무겁다', '개인들', '스탁', '희비', '수사' , '황교안vs이낙연',
'기수론', '옥석라려라', '위험', '기대감', '진입', '이재용', '메가엠디', '초록뱀',
'분석', '대란', '1개', '문재인+이낙연', '진짜', '선출', '들썩', '오늘', '쏠려', '급증', 
'씨젠', '재개', '열풍', '해체', '반복된', '관심', '주식시장', '인연', 'HOT한', '수상한',
'안희정', '써니전자', '겨울관련주' , '동아지질', '정보', '전파기지국', '경신',
'사퇴', '웅진', '전총리', '케이씨피드', '유신', '정계복귀', '선언하자', '최고가경신',
'주가폭등', '일제히', '종목', '확대', '총리', '李총리', '발병소식', '새로운', '가시화',
'여름관련주', '대망론', '유력설', 'SM', '키워드', '급상승', '인기', '탄력', '주장', '띄우기',
'연관', '웰크론', '삼보산업', '일축', '대선', '달군', '주요', '움직임', 'MB', 'KNN',
'윌비스', '적발', '최대주주', '대주주', '대정부질문', '복귀설', '임명', '이상한', '유엔연설',
'정계복귀설', '고려아연', '확산세', '영향', '정치관련', '올랐다', '선고', '남북', '방식따라', 
'2라운드', '정산애강', '강세', '울상', '투자', '권고', '수주', '가격부담', '유통', '지속',
'공급원활', '부정적', '대원전선', '대호에이엘', '제룡전기', '현대로템', '남광토건',
'서암기계공업', 'HDC아이콘트롤스', '대아티아', '에코마이스터', '도화엔지니어링',
'결정', '나온다', '차이', '품절대란', '생산', '피씨디렉트', '구축', '녹십자홀딩스', '산업',
'인수설', '라온시큐어', '출마', '언급후', '형성', '협력', 'LS', '주식', '셀트리온제약',
'오거돈', '엇길란', '삼표시멘트', 'SK바이오랜드', '긴급승인', '미국시장', '코젠바이오텍',
'두산그룹', '대국민사', '폭락', 'vs', '전문', '소송', '빅히트', '카모스타트메실산염', '진출',
'부광약품', '웹젠', '급부상', '샘표등', '기업인', '임상재개', '임상시험', 'ETN등', '에코바이오',
'요청', '종근당', '마크로젠등', '비상교육', '비에이치', '침입', '확진자', 'LG이노텍',
'보성파워텍', '코아시아', '키이스트', '바른손', '도래', '바른손앤에', 'ENM', '가능', '제작사',
'모나리자', '수상', '롯데그룹', '차량', '에탈올', '발언', '합병설', '의심환자', '거론', '배터리3사까지',
'파루', '서린바이오', '화학', '중앙에너비스', '여파' , '138개', '면역력', '이광재', '컴백으', '한진칼우',
'확전소식', '한진칼', 'HDC현대산업개발', '국회의장', '텔콘RF제약', '인수', '김진표', '보조금',
'국무총리', '젬백스', '개봉', '반등', '우리기술투자등', '새주인', '우정바이오등', '인수합병',
'품귀현상', 'HDC그룹', '코스닥', '제일바이오', '헝셩그룹',' 급물살', '이어갈', '사용소식', '주목해야',
'씨티젠', '아시아나IDT등', '진영', '목표', '연관설', '임명직', '안전한', '각종', '신사업', '동진쎄미켐',
'대세', '소규모정비', '5대', '주목하자', '10월', '1월', '압도적', '시행', '표명', '이어가며',
'이녹스첨단소재', '설립', '펀드', '테마', '무슨', '두산퓨얼셀', '남북펄', '상상인', '온다', '연관성',
'소재', '볼까', '예찰', '뭉칫돈', '2주차', '판매중지', '시황변동', '파인텍', '심각', '발생소식',
'인수전', '환자소식', '마니커', '예상', '의존', '한일단조', '4주차', '크라운제', '하림', '3주차',
'강세인', '파기환송', '등락', '급등하', '약세장에서', '모색중', '이틀째', '가온미디어', '방침',
'본격화', '에어부산'
]

# %%
drop_list = drop_people + drop_verb + drop_etc

for i in range(len(df)):
    if df.Theme[i] in drop_list:
        df.drop(index=[i], inplace=True)
    elif re.search('[0-9]+[시분]', df.Theme[i]) != None:
        df.drop(index=[i], inplace=True)
    elif re.search('[\-\&ㆍ‧\"/\%\\↑→\+]', df.Theme[i]) != None:
        df.drop(index=[i], inplace=True)

df.reset_index(drop=True, inplace=True)
df.shape
df.to_csv('data_filtered_v1.csv')

# %%
df.Theme.values
# Out:
# array(['방탄소년단', '애국', '5G', '보톡스', '코로나19', '제약', '치료제', '황우석', '마스크',
#        '부재', '원격진료', '수소경제', '코로', '구충제', '시대', '의료봉사', '양돈주', '자동화',
#        'SNS', '생체인식', '낙폭', '키오스크', '대북', 'PC', '줄기세포치료제', '기생충', '희토류',
#        '대선주자', '진단키트', '여행', '안랩', '더블매치', '봉사', '사진', '2차전지', '방역진단',
#        '대북정책', '비료', '헬스케어', '해저터널', '자동차부품', '자율주행차', '키즈', 'LCD장비',
#        'LED', '세포치료제', '폭염', 'NAND', '복원', '폴더블폰', '조선기자재', '전력설비', '카지노',
#        '태블릿PC', '조림사업', '시스템반도체', '다이오드', 'AI', '장비', 'CNT', '회장', '진단시약',
#        '항공기부품', '제대혈', '전기차', '농업', '방위산업', '개성공단', '장마', '편의점', 'LCC',
#        '조선', '처리장치', '펜벤다졸', '신공항', 'NFC', '줄기세포', '엔터테인먼트', '면역항암제',
#        '평화공원', '창투사', '면역세포치료제', 'VR', 'ASF', '테마파크', 'Drone', '취업',
#        '네트워크통합', '건설사', '지진', '가스터빈', '수소차', '옥석가려라', '은행', '제약업체', '증권사',
#        '부품', 'ESS', '자원', '노인복지', '금융자동화기기', '스마트그리드', '테러', 'BTS',
#        '보툴리눔톡신', '아이폰', '슈퍼박테리아', '뉴딜', '육계', '방역진단가축', '스마트팩토리', '온라인광고',
#        '재택근무', '소셜네트워크서비스', '바이오의약품', '모더', '임플란트', '자전거', 'AR', '수산',
#        '스마트폰', '게임관련', '군함', '석유', '국가보안법', '그래핀', '커피', '에어컨', '혈장치료',
#        '손소독제', 'GV80', '신종코로', '타이어', '휴대폰부품', '엔젤산업', '영화', '물류', '중국기업',
#        '출산장려정책', '제지', '차량용블랙박스', '전선', '가스관사업', '제습기', '자원개발', '주류업',
#        '영상콘텐츠', '전자화폐', '반일', '제4이동통신', 'CAR', '화장품', '사물인터넷', 'LNG',
#        'SSD', '해운', '홈쇼핑', '밥솥', '탄소배출권', '바이러스', '중소형', 'MVNO', '우한폐렴',
#        '부품주', '폐기물처리', '비철금속', '블록체인', '도시가스', '캐릭터상품', '음식료업종', '보안주',
#        '이엠코리아', '비트코인', '음성인식', '핵융합에너지', 'CCTV', 'LED장비', '백신', '손해보험',
#        '전자파', '바이오', '리츠', '온실가스', '무선충전기술', '통신장비', '광고', 'FinTech',
#        '우주항공산업', '치매', 'FPCB', '디피씨', '거래가', 'MRO', '폐렴', '풍력에너지', 'GTX',
#        '소매유통', '전지', '코로나바이러스', '음압병동', '제조', '디스플레', '공기청정기', '페인트',
#        '광물자원개발', '의료기기', '생명보험', '프린터', '백화점', '화학섬유', 'CCTV＆DVR',
#        'REITs', '증권', '사료', '오공', '물리', '전기자전거', '교육', '공작기계', '액화석유가스',
#        '면세점', '석유화학', '수소', '스마트공장', '게임', 'pipe', '건설기계', '컴퓨팅', '이동통신',
#        '없다”', '시스템통합', '불매운동', 'KIOSK', '적층세라믹콘덴서', '콘크리트', 'SPAC', '삼성페',
#        '지주사', '상한', '사업', '웰스바이오', '자동차', '반도체', '남북경협', '종합상사', '원자력발전',
#        '금강산관광', '수혜주', '태양광에너지', '특정인물', '주요종목', '종합물류관련주', '광역급행철',
#        'Gas', '액화천연가스', '인터넷은행', '中폐렴', '“이낙연', '낸드', '방한', '배출권', '비보존',
#        'PCB생산', 'LED산업', '수산주', '주류', '정보보안', '바이오시밀러', '보험', '농업주',
#        'LBS관련주', '태양광', '패션', '골드선물', '연말', '항공', '흑사병', '기자수첩', '미세먼지',
#        '미래차', '돼지열병', '장관', '경협', '닭고기', '4대강', '북한', '육류', '아프리카돼지열병',
#        'DMZ', '탄소섬유', '푸른기술', '로저스', '일본불매', '은선물', '애국심', '결제', '보안',
#        '덱사메타손', '남북철', '클로로퀸', '렘데시비르', '첨생법', '이뮨메드', '랄록시펜', '언택트',
#        '나파모스타트', '메트포르민', '아시아', '애플', '닭', '수소산업', '드론', '배터리', 'QR코드',
#        'SK케미칼', '부각', '이노비오', '재생에너지', 'SK바이오팜', '낮춘다', '삼성', '이지바이오',
#        '임박', '감소', '임상', '우주선', '방산', '케어랩스', '4차산업', '재확산', '고려제약등',
#        '신재생에너지', '조선업', '괴질', '디지털화폐', '유니슨', '수입된다면', '그린뉴딜', '3대',
#        '백신개발', '원격의료', '월드컵', '옵티시스', 'BLU제조', '정유', '비대면', '양자', '대북철',
#        '이낙연\xa0황교안', '캠핑', 'qr코드', '의료', '혈장치료제', '노바백스', '하이드록시클로로퀸',
#        '전자인증', '비메모리', '소독제', '분유', '클라우드', '녹십자', '시티', '온라인교육', '전자서명',
#        '빅데이터', '대한항공', '전자결제', '공급하는데', '무인기기', '방사광가속기', '경제협력', '램데시비르',
#        '진료', '영화관', '유비케어', '건설', '에이프로젠', '신풍제약', '한국정보인증', '비접촉', '로봇',
#        '스마트워크', '경협주', '시멘트', '진단키트시약', '국제유', '인공호흡기', '지능형전력망', '카모스타트',
#        'Graphene', '홈네트워크', '당뇨병', '무역전쟁', '원격', '친환경', '코오롱', '와파',
#        '공공와파', '원유', '레몬', '비대면진료', '이버멕틴', '음압병실', '콘텐츠', 'LCD', '간편식',
#        '한진', '알콜', '손세정제', '세정제', '19', '한진그룹', '병실', '진단장비', '예방',
#        '진단키드', '돌파', '양성반응', '신약', '폐질환', '통일교', '진단', '자율주행', '김빛내리',
#        '인공지능', '말라리아', '아지트로마이신', '한타바이러스', '혈장', '골판지', '택배', '식품', '원전',
#        '테슬라', '언팩', '“코로나19', '“기생충', '`접히니`', 'Z플립', '에탄올', '친환경차', '방역',
#        '중국', '코디엠', '검진키트', '라텍스', '펭수', '마스크의료기기', '호흡기', '가상화폐',
#        '무선이어폰', '“부품', '긴급사용제', '일자리', '보건위생', '사스', '위생용품', '수소연료전지차',
#        '유', '피격', '데이터3법', '라텍스장갑', '개미', '3법', '방탄', 'OLED', '이어폰',
#        '아시아나항공', '셀트리온', '구리', '건강', 'OTT', '미래에셋대우', '금호산업', '의약품',
#        '애경산업', '김철민', '아기상어', '항공화물운송', '급물살', '폐기물', '의료정보시스템', '페니실린',
#        '불화수소', '가구', '그래픽', '마이크로바이옴', '개구충제', '알츠하이머', '불매', '스마트스터디',
#        '갤폴드', '완구', '삼성출판사', '인테리어', '암호화폐', '드라마', '삼성전자', '가금류', '마리화',
#        '현대차', '현대車', '동물의약품', '우리기술투자', '돼지고기', '알벤다졸', '양돈업계', '농기계',
#        '열병', '폴드', '원자력', '대체육', '증강현실', '덴티움', '양돈', '입시', '돈육', '화재',
#        '대입', '에칭가스', '일본', '韓日', '음식료품', 'AI”', '수산물', '“화장품', '건강기능식품',
#        '웹툰', '3D프린터', '속옷', 'ai', '가정용기기', '출판', '화이트리스트', '상업서비스',
#        '日수출규제', '첨단소재', '디스플레이장비', '수소시장', '건축자재', 'PCB'], dtype=object)

# %%
#change

복원 -> 4대강
코로 -> 코로나
모더 -> 모더나
다시보 -> 다시보기
19 -> 코로나
코로나19 -> 코로나
LBS관련주 -> LBS
디스플레 -> 디스플레이
마리화 -> 마리화나
